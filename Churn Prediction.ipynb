# %%
# Project on Chrun Prediction (By Abhay Kumar Singh)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_frame=pd.read_excel("/kaggle/input/datasets/abhaykumar3650/telco-customer-churn/Telco_customer_churn.xlsx")

# %%
data_frame.shape
# Out:
# (7043, 33)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
data_frame['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(data_frame['Tenure Months'], bins=30, kde=True)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('Distribution of Tenure Months vs no of customers')
plt.show()

# %%
data_frame['Tenure Months'].max()
# Out:
# 72

# %%
data_frame['Tenure Months'].min()
# Out:
# 0

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y='Tenure Months', x='Churn Label', data=data_frame)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('churn vs Tenure months')
plt.show()

# %%
data_frame['Churn Label'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
plt.figure(figsize=(8,5))
sns.histplot(data_frame['Monthly Charges'], bins=30, kde=True)
plt.xlabel('Monthly charges')
plt.ylabel('Customer count')
plt.title('Distribution of Monthly charge vs no of customers')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y='Monthly Charges', x='Churn Label', data=data_frame)
plt.xlabel('Tenure Months')
plt.ylabel('Customer count')
plt.title('churn vs  monthly charges')
plt.show()

# %%
data_frame[data_frame['Churn Label']=='targetes']['Monthly Charges'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25   NaN
# 0.50   NaN
# 0.75   NaN
# Name: Monthly Charges, dtype: float64

# %%
data_frame[data_frame['Churn Label']=='No']['Monthly Charges'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    25.100
# 0.50    64.425
# 0.75    88.400
# Name: Monthly Charges, dtype: float64

# %%
data_frame['Monthly Charges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: Monthly Charges, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Churn Label', data=data_frame)
plt.xlabel('Churn Label')
plt.ylabel('Customer count')
plt.title('Churn Label vs Customer Count')
plt.show()

# %%
data_frame['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
data_frame['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.countplot( x = 'Contract', hue = 'Churn Label', data = data_frame)
plt.xlabel('Contract')
plt.ylabel('Count')
plt.title('Contract v/s Count')
plt.show()

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
data_frame['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.countplot( x = 'Internet Service', hue = 'Churn Label', data = data_frame)
plt.xlabel('Internet Service')
plt.ylabel('Count')
plt.title('Internet Service v/s Count')
plt.show()

# %%
data_frame['Payment Method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
data_frame['Payment Method'].value_counts()
# Out:
# Payment Method
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.countplot( x = 'Payment Method', hue = 'Churn Label', data = data_frame)
plt.xlabel('Payment Method')
plt.ylabel('Count')
plt.title('Payment Method v/s Count')
plt.show()

# %%
data_frame['Tech Support'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
data_frame['Tech Support'].value_counts()
# Out:
# Tech Support
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
plt.figure( figsize = (8, 5) ) #height and width
sns.countplot( x = 'Tech Support', hue = 'Churn Label', data = data_frame)
plt.xlabel('Tech Support')
plt.ylabel('Count')
plt.title('Tech Support v/s Count')
plt.show()

# %%
avg_tenure=data_frame.groupby("Churn Label")['Tenure Months'].mean()

# %%
avg_tenure
# Out:
# Churn Label
# No     37.569965
# Yes    17.979133
# Name: Tenure Months, dtype: float64

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
numerical_cols=['Tenure Months', 'Monthly Charges', 'Churn Value', 'Churn Score', 'CLTV']

# %%
correlation_matrix=data_frame[numerical_cols].corr()

# %%
correlation_matrix
# Out:
#                  Tenure Months  Monthly Charges  Churn Value  Churn Score  \
# Tenure Months         1.000000         0.247900    -0.352229    -0.224987
# Monthly Charges       0.247900         1.000000     0.193356     0.133754
# Churn Value          -0.352229         0.193356     1.000000     0.664897
# Churn Score          -0.224987         0.133754     0.664897     1.000000
# CLTV                  0.396406         0.098693    -0.127463    -0.079782
#
#                      CLTV
# Tenure Months    0.396406
# Monthly Charges  0.098693
# Churn Value     -0.127463
# Churn Score     -0.079782
# CLTV             1.000000

# %%
from matplotlib.colors import Normalize
contract_churn=pd.crosstab(data_frame['Contract'], data_frame['Churn Label'], normalize='index')
contract_churn
# Out:
# Churn Label           No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
data_frame['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2         820.5
# 3       3046.05
# 4        5036.3
#          ...
# 7038     1419.4
# 7039     1990.5
# 7040     7362.9
# 7041     346.45
# 7042     6844.5
# Name: Total Charges, Length: 7043, dtype: object

# %%
data_frame['Total Charges']=pd.to_numeric(data_frame['Total Charges'], errors='coerce')
data_frame['Total Charges']
# Out:
# 0        108.15
# 1        151.65
# 2        820.50
# 3       3046.05
# 4       5036.30
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score

y_pred = clf_model.predict(features)
y_prob = clf_model.predict_proba(features)[:,1]

print("Precision:", precision_score(target, y_pred))
print("Recall:", recall_score(target, y_pred))
print("F1:", f1_score(target, y_pred))
print("ROC-AUC:", roc_auc_score(target, y_prob))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/3391643953.py in <cell line: 0>()
#       1 from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score
#       2
# ----> 3 y_pred = clf_model.predict(features)
#       4 y_prob = clf_model.predict_proba(features)[:,1]
#       5
#
# NameError: name 'clf_model' is not defined
